# %% [markdown]
# #  Introduction

# %% [markdown]
# Dans ce Lab, nous allons vous initier au traitement d’images  en utilisant la bibliothèque OpenCV. L'objectif n'est pas d'apprendre la bibliothèque en détail, mais d'en apprendre suffisamment pour que vous soyez capable de réaliser quelques manipulations de bases.
#
# OpenCV est l’une des bibliothèques les plus utilisées pour les applications de vision par ordinateur (Computer Vision, en anglais). Cette bibliothèque est principalement utilisée pour construire des applications de vision par ordinateur et d'apprentissage automatique. Elle possède plusieurs algorithmes optimisés. Ces algorithmes peuvent réaliser beaucoup de tâches telles que la détection et la reconnaissance des visages, l’identification des objets et bien d'autres. Vous pouvez aussi l’utiliser pour manipuler une image dans le but d’extraire des informations.

# %% [markdown]
# # Pourquoi utiliser OpenCV ?

# %% [markdown]
# Il y a de multiples raisons d'utiliser OpenCV qui sont simples et évidentes.
#
#     -OpenCV est simple d'utilisation et puissante
#
#  En effet, le nom des fonctions est simple et relate effectivement leur rôle.
#
#     -OpenCV est gratuite
#
# ce qui probablement doit plaire à beaucoup de sa communauté
#
#     -Le fait d'être gratuite ne l'empêche aucunement d'être puissante, quoi de plus normal pour une bibliothèque énormément utilisée par de gros industriels (Intel, Willow Garage, probablement Google) et de nombreuses universités  telles que l'université des Antilles, mais aussi L'UPMC à Paris.
#
#     -Ses sources sont modifiables et accessibles.
#
# Ce dernier point est un argument de persuasion majeur pour les maniaques du contrôle qui sont persuadés qu'ils vont modifier la librairie et apporter une modification révolutionnaire, mais qui en vérité ne le feront jamais! En autre cela permet aux universités et industriels d'adapter la bibliothèque à leurs besoins, mais aussi de proposer des modifications via la célèbre plateforme Github ou l'on peut trouver les sources d'OpenCV : lien.
#
#     -Enfin pour finir, cette librairie est disponible dans de nombreux langages,
#
# Python, Java, Matlab, C#, C++, JavaScript, etc....  Attention cependant, cela ne veut pas dire que les binding d'OpenCV que vous trouvez dans ces langages sont officiels. Pour preuve, le binding python, utilisé par toute la communauté, n'est pas développé par OpenCV.org.

# %% [markdown]
# # Installation de la bibliothèque OpenCV

# %% [raw]
# pip install opencv-python

# %% [markdown]
# # Comment charger et enregistrer une image avec OpenCV?

# %% [markdown]
# Pour utiliser OpenCV, il est nécessaire de la charger en mémoire. Cela se fait en tapant la ligne :

# %%
import cv2

# %% [markdown]
# Questions 1: Charger une image à l'aide de la fonction imread, la sauvegarder à l'aide de la fonction imwrite et l'afficher

# %%
image =cv2.imread("src/poisson.png")

# %% [markdown]
# # Comment afficher une image avec OpenCV?

# %% [markdown]
# Si tu veux afficher une image à l'écran, il te faudra tout d'abord utiliser la fonction namedWindow pour créer une fenêtre graphique.
#
# Puis, il faut utiliser la fonction imshow qui prend pour paramètres le nom de la fenêtre et l'image à afficher.
#
# La fonction  waitKey permettra ensuite de mettre la fenêtre en attente d'un événement.

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow("image",image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Transformer une image RVB (rouge bleu vert) en niveaux de gris
# Transformer une image RVB en niveaux de gris en utilisant le format cvtColor puis la sauvegarder dans un fichier sur le disque en utilisant imwrite :

# %%
newImg = image.copy()
gray = cv2.cvtColor(newImg, cv2.COLOR_BGR2GRAY)
cv2.imwrite("src/gray.png",gray)
cv2.imshow('image',gray)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Taille d'une image
# Redimensionner l'image RVB l'aide de la fonction resize et l'afficher

# %%
#Taille d'une image
(h, w) = image.shape[:2]  #shape holds a tuple(rows,columns, channels), extract the rows and columns values from the shape tuple
print("la taille originale de l'image est :",(h,w))
img = cv2.resize(image,(500,700),interpolation = cv2.INTER_AREA)
(h, w) = img.shape[:2]
print("la nouvelle taille de l'image est :",(h,w))
cv2.imwrite("C:/Users/naoue/Documents/MCVision/Seance1/image2.png",img)

# %%
#image h and w
# print them
# resize to 700, 500
# save image2.png

(h, w) = image.shape[:2]
print("Les dimensions de l'image originale: ", (h, w))
new_height = 500
new_width = 700
image2 = cv2.resize(image, (new_height, new_width), interpolation= cv2.INTER_AREA)
(n_w, n_h) = image2.shape[:2]
print("Les nouvelles dimensions de l'image2: ", (n_w, n_h))
cv2.imwrite("src/resized_fish.png", image2)
cv2.imshow("image2", image2)
cv2.waitKey(0)

# %% [markdown]
# # La bibliothèque matplotlib pour l'affichage d'une image

# %% [markdown]
# Matplotlib est une des bibliothèques python les plus utilisées pour représenter des graphiques en 2D.
# Elle permet de produire une grande variété de graphiques et ils sont de grande qualité.
#
# Le module pyplot de matplotlib est l’un de ses principaux modules.
# Il regroupe un grand nombre de fonctions qui servent à créer des graphiques et les personnaliser (travailler sur les axes, le type de graphique, sa forme et même rajouter du texte).

# %%
import matplotlib.pyplot as plt   # pip install matplotlib

# %%
plt.axis("off")
plt.title("image originale")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Convertir l’image RVB en image HSV, la sauvegarder et l'afficher

# %%
hsv_poisson = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
cv2.imwrite("src/image_hsv.png",hsv_poisson)
#cv2.imshow("hsv_image", hsv_poisson)
#cv2.waitKey(0)

# %% [markdown]
# # Modifier quelques pixels de l’image RVB en niveau de gris et l'afficher

# %%
p=image[50,60] #On accède au pixel situé à la ligne 50 et à la colonne 60 de l'image
p    #composantes B, G, R

# %% [markdown]
# # Question: décrire le résultat de ce code

# %%
image[10:110,10:110]=[50,50,50]
cv2.imshow("Original_image_modifiee", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Réponse

# %%
# on a transformé un carré dans l'image en gris (R: 50, G: 50, B:50).

# %% [markdown]
# # pyrUp() & pyrDown()  pour le changement d'échelle

# %% [markdown]
# pyrUp() : doubler les dimensions de l'image
#
# pyrDown() : divise par 2 les dimensions de l'image

# %%
img=cv2.imread("src/poisson.png")
scaleDown = cv2.pyrDown(img)
scaleUp = cv2.pyrUp(img)

cv2.imshow('image', img)
cv2.imshow('scaleDown', scaleDown)
cv2.imshow('scaleUp', scaleUp)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Redimensionner l'image RVB l'aide de la fonction resize et l'afficher

# %%
poisson=cv2.imread("src/poisson.png")

print('Original Dimensions : ',poisson.shape)
 
width = 350
height = 450
dim = (width, height)
 
# resize image
resized = cv2.resize(poisson, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Application 1 : Afficher 2 images sous la même fenêtre à l'aide de matplotlib

# %% [markdown]
# Afficher les deux images star.png et phone.png dans la même fenêtre l'aide de matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
star = cv2.imread("src/star.png", cv2.IMREAD_COLOR)
phone = cv2.imread("src/phone.png", cv2.IMREAD_COLOR)
rgb_star = cv2.cvtColor(star, cv2.COLOR_BGR2RGB)
rgb_phone = cv2.cvtColor(phone, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.title("phone and start")
resized_star = cv2.resize(rgb_star, (2555, rgb_star.shape[0],), interpolation = cv2.INTER_AREA)
plt.imshow(np.concatenate((rgb_phone, resized_star), axis=0))
#plt.imshow(resized_star)

plt.show()

# %%
print(resized_star.shape)
print(phone.shape)

# %%
import matplotlib.pyplot as plt
fig, axis = plt.subplots(2, 1)

star = cv2.imread("src/star.png")
phone = cv2.imread("src/phone.png")

star_rgb = cv2.cvtColor(star, cv2.COLOR_BGR2RGB)
phone_rgb = cv2.cvtColor(phone, cv2.COLOR_BGR2RGB)

axis[0].axis("off")
axis[0].set_title("star")
axis[0].imshow(star_rgb)

axis[1].axis("off")
axis[1].set_title("phone")
axis[1].imshow(phone_rgb)

plt.show()

# %% [markdown]
# # Partie 2 : manipulation d’une séquence vidéo:

# %% [markdown]
# Capture d'image de la caméra

# %%
import matplotlib.pyplot as plt
##  Initialisation de l'appareil photo
cam = cv2.VideoCapture(0)

## Obtenir le cadre
ret, frame = cam.read()

## Conversion de tableau de couleurs :: BGR -> RVB
rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

## Sortie écran
plt.figure(figsize=(10,10))
plt.title('usb-cam')
plt.axis('off')
plt.imshow(rgb)
plt.show()

## Libération de la caméra
cam.release()

# %% [markdown]
# # Lecture vidéo partir de la caméra du pc

# %%
# Import the required modules
# %pylab inline 
import cv2
from IPython.display import clear_output

# Grab the input device, in this case the webcam
# You can also give path to the video file
vid = cv2.VideoCapture(0)

# Put the code in try-except statements
# Catch the keyboard exception and 
# release the camera device and 
# continue with the rest of code.
try:
    while(True):
        # Capture frame-by-frame
        ret, frame = vid.read()
        if not ret:
            # Release the Video Device if ret is false
            vid.release()
            # Message to be displayed after releasing the device
            print("Released Video Resource")
            break
        # Convert the image from OpenCV BGR format to matplotlib RGB format
        # to display the image
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Turn off the axis
        axis('off')
        # Title of the window
        title("Input Stream")
        # Display the frame
        imshow(frame)
        show()
        # Display the frame until new frame is available
        clear_output(wait=True)
except KeyboardInterrupt:
    # Release the Video Device
    vid.release()
    # Message to be displayed after releasing the device
    print("Released Video Resource")

# %% [markdown]
# # Application 2 : Lecture d'une vidéo sauvegarder dans votre pc

# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output

video = cv2.VideoCapture("src/videoplayback.mp4")

try:
    ret, frame = video.read()

    while ret:
        plt.title("video")
        plt.axis("off")
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plt.imshow(frame_rgb)
        plt.show()
        clear_output(wait=True)
        ret, frame = video.read()

finally :
    video.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 20
#      16         clear_output(wait=True)
#      17         ret, frame = video.read()
#      18
#      19 finally :
# ---> 20     video.release()
#
# File ~/programming/school/computer_vision/lab1/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:646, in show(*args, **kwargs)
#     602 """
#     603 Display all open figures.
#     604
#    (...)    643 explicitly there.
#     644 """
#     645 _warn_if_gui_out_of_main_thread()
# --> 646 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/programming/school/computer_vision/lab1/.venv/lib/python3.13/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import IPython.display 

video = cv2.VideoCapture("src/videoplayback.mp4")

while True:
    plt.axis("off")
    plt.title("video")
    ret, frame = video.read()
    if not ret:
        break
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame_rgb)
    plt.show()
    clear_output(wait=True)

video.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/programming/school/computer_vision/lab1/.venv/lib/python3.13/site-packages/PIL/ImageFile.py:663, in _save(im, fp, tile, bufsize)
#     662 try:
# --> 663     fh = fp.fileno()
#     664     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 15
#      11     if not ret:
#      12         break
#      13     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      14     plt.imshow(frame_rgb)
# ---> 15     plt.show()
#      16     clear_output(wait=True)
#      17
#      18 video.release()
#
# File ~/programming/school/computer_vision/lab1/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:646, in show(*args, **kwargs)
# ...
